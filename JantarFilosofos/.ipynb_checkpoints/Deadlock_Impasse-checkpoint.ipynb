# %%
from datetime import datetime 
from time import sleep, strftime, gmtime
from threading import Thread
from random import randrange

# %%
class Filosofo:
    
    __n_forks = 0
    __cnt_pensou = 0
    __cnt_comeu = 0
    __cnt_garfo = 0
    all_forks = 5
    
    def __init__(self, nome, num):
        self.nome = nome
        self.num = num
        
    def  eat(self):
        print("\n[{}][{}:{}] Iniciou a comer."
              .format(datetime.now().strftime('%d-%m-%Y %H:%M:%S'),self.nome,self.num))
        self.__cnt_comeu += 1
        sleep(randrange(1,5))# indeterminismo
        print("\n[{}][{}:{}] Terminou de comer."
              .format(datetime.now().strftime('%d-%m-%Y %H:%M:%S'),self.nome,self.num))
        pass
    
    def  put_fork(self):
        if self.__n_forks > 0:
            self.__n_forks -= 1
            Filosofo.all_forks += 1
            if self.__n_forks == 1:
                print("\n[{}][{}:{}] Soltou o primeiro garfo."
                      .format(datetime.now().strftime('%d-%m-%Y %H:%M:%S'),self.nome,self.num))
            elif self.__n_forks == 0:
                print("\n[{}][{}:{}] Soltou o segundo garfo."
                      .format(datetime.now().strftime('%d-%m-%Y %H:%M:%S'),self.nome,self.num))
        pass
    
    def  take_fork(self):
        while(Filosofo.all_forks < 1):
            if self.__n_forks == 0:
                print("\n[{}][{}:{}] Aguardando o primeiro garfo."
                  .format(datetime.now().strftime('%d-%m-%Y %H:%M:%S'),self.nome,self.num))
            elif self.__n_forks == 1:
                print("\n[{}][{}:{}] Aguardando o segundo garfo."
                  .format(datetime.now().strftime('%d-%m-%Y %H:%M:%S'),self.nome,self.num))
            sleep(randrange(1,5))# indeterminismo
        self.__cnt_garfo += 1
        self.__n_forks += 1
        Filosofo.all_forks -= 1
        if self.__n_forks == 1:
            print("\n[{}][{}:{}] Pegou o primeiro garfo."
                  .format(datetime.now().strftime('%d-%m-%Y %H:%M:%S'),self.nome,self.num))
        elif self.__n_forks == 2:
            print("\n[{}][{}:{}] Pegou o segundo garfo."
                  .format(datetime.now().strftime('%d-%m-%Y %H:%M:%S'),self.nome,self.num))
        sleep(5)
        pass
    
    def  think(self):
        print("\n[{}][{}:{}] Está pensando..."
              .format(datetime.now().strftime('%d-%m-%Y %H:%M:%S'),self.nome,self.num))
        self.__cnt_pensou += 1
        sleep(randrange(1,5))# indeterminismo
        print("\n[{}][{}:{}] Ficou faminto."
              .format(datetime.now().strftime('%d-%m-%Y %H:%M:%S'),self.nome,self.num))
        pass

    def exist(self):
#       Ciclos de realizações
        for i in range(1,3):
            self.think();
            self.take_fork();
            self.take_fork();
            self.eat();
            self.put_fork();
            self.put_fork();

# %%
for i in range(1,6):
    f = Filosofo("FILOSOFO",i)
    t = Thread(target=f.exist)
    t.start()
    t.join()
    print(f.__dict__)
print("=========== Fim da execução!!! ===========")
# Out:
# [10-03-2019 11:00:32][FILOSOFO:1] Está pensando...
#
# [10-03-2019 11:00:32][FILOSOFO:1] Ficou faminto.
#
# [10-03-2019 11:00:32][FILOSOFO:1] Pegou o primeiro garfo.
#
# [10-03-2019 11:00:32][FILOSOFO:2] Está pensando...
#
# [10-03-2019 11:00:32][FILOSOFO:2] Ficou faminto.
#
# [10-03-2019 11:00:32][FILOSOFO:2] Pegou o primeiro garfo.
#
# [10-03-2019 11:00:32][FILOSOFO:3] Está pensando...
#
# [10-03-2019 11:00:32][FILOSOFO:3] Ficou faminto.
#
# [10-03-2019 11:00:32][FILOSOFO:3] Pegou o primeiro garfo.
#
# [10-03-2019 11:00:32][FILOSOFO:4] Está pensando...
#
# [10-03-2019 11:00:32][FILOSOFO:4] Ficou faminto.
#
# [10-03-2019 11:00:32][FILOSOFO:4] Pegou o primeiro garfo.
#
# [10-03-2019 11:00:32][FILOSOFO:5] Está pensando...
#
# [10-03-2019 11:00:32][FILOSOFO:5] Ficou faminto.
#
# [10-03-2019 11:00:32][FILOSOFO:5] Pegou o primeiro garfo.
#
# [10-03-2019 11:00:37][FILOSOFO:1] Aguardando o segundo garfo.
#
# [10-03-2019 11:00:37][FILOSOFO:2] Aguardando o segundo garfo.
#
# [10-03-2019 11:00:37][FILOSOFO:3] Aguardando o segundo garfo.
#
# [10-03-2019 11:00:37][FILOSOFO:4] Aguardando o segundo garfo.
#
# [10-03-2019 11:00:37][FILOSOFO:5] Aguardando o segundo garfo.
#
# [10-03-2019 11:00:38][FILOSOFO:2] Aguardando o segundo garfo.
#
# [10-03-2019 11:00:39][FILOSOFO:5] Aguardando o segundo garfo.
#
# [10-03-2019 11:00:40][FILOSOFO:3] Aguardando o segundo garfo.
#
# [10-03-2019 11:00:41][FILOSOFO:1] Aguardando o segundo garfo.
#
# [10-03-2019 11:00:41][FILOSOFO:2] Aguardando o segundo garfo.
#
# [10-03-2019 11:00:41][FILOSOFO:4] Aguardando o segundo garfo.
#
# [10-03-2019 11:00:41][FILOSOFO:5] Aguardando o segundo garfo.
#
# [10-03-2019 11:00:42][FILOSOFO:4] Aguardando o segundo garfo.
#
# [10-03-2019 11:00:42][FILOSOFO:5] Aguardando o segundo garfo.
#
# [10-03-2019 11:00:43][FILOSOFO:3] Aguardando o segundo garfo.
#
# [10-03-2019 11:00:44][FILOSOFO:3] Aguardando o segundo garfo.
#
# [10-03-2019 11:00:44][FILOSOFO:5] Aguardando o segundo garfo.
#
# [10-03-2019 11:00:45][FILOSOFO:1] Aguardando o segundo garfo.
#
# [10-03-2019 11:00:45][FILOSOFO:2] Aguardando o segundo garfo.
#
# [10-03-2019 11:00:46][FILOSOFO:1] Aguardando o segundo garfo.
#
# [10-03-2019 11:00:46][FILOSOFO:4] Aguardando o segundo garfo.
#
# [10-03-2019 11:00:47][FILOSOFO:3] Aguardando o segundo garfo.
#
# [10-03-2019 11:00:48][FILOSOFO:3] Aguardando o segundo garfo.
#
# [10-03-2019 11:00:48][FILOSOFO:4] Aguardando o segundo garfo.
#
# [10-03-2019 11:00:48][FILOSOFO:5] Aguardando o segundo garfo.
#
# [10-03-2019 11:00:49][FILOSOFO:2] Aguardando o segundo garfo.
#
# [10-03-2019 11:00:49][FILOSOFO:3] Aguardando o segundo garfo.
#
# [10-03-2019 11:00:50][FILOSOFO:1] Aguardando o segundo garfo.
#
# [10-03-2019 11:00:50][FILOSOFO:2] Aguardando o segundo garfo.
#
# [10-03-2019 11:00:50][FILOSOFO:4] Aguardando o segundo garfo.
#
# [10-03-2019 11:00:51][FILOSOFO:3] Aguardando o segundo garfo.
#
# [10-03-2019 11:00:51][FILOSOFO:4] Aguardando o segundo garfo.
# [10-03-2019 11:00:51][FILOSOFO:5] Aguardando o segundo garfo.
#
#
# [10-03-2019 11:00:52][FILOSOFO:2] Aguardando o segundo garfo.
#
# [10-03-2019 11:00:53][FILOSOFO:1] Aguardando o segundo garfo.
#
# [10-03-2019 11:00:54][FILOSOFO:2] Aguardando o segundo garfo.
#
# [10-03-2019 11:00:54][FILOSOFO:3] Aguardando o segundo garfo.
#
# [10-03-2019 11:00:54][FILOSOFO:5] Aguardando o segundo garfo.
#
# [10-03-2019 11:00:55][FILOSOFO:2] Aguardando o segundo garfo.
# [10-03-2019 11:00:55][FILOSOFO:3] Aguardando o segundo garfo.
#
#
# [10-03-2019 11:00:55][FILOSOFO:4] Aguardando o segundo garfo.
#
# [10-03-2019 11:00:56][FILOSOFO:1] Aguardando o segundo garfo.
#
# [10-03-2019 11:00:57][FILOSOFO:1] Aguardando o segundo garfo.
#
# [10-03-2019 11:00:57][FILOSOFO:4] Aguardando o segundo garfo.
