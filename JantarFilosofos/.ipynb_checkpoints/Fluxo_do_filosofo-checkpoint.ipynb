# %%
from datetime import datetime 
from time import sleep, strftime, gmtime
from threading import Thread
from random import randrange

# %%
class Filosofo:
    
    __n_forks = 0
    all_forks = 5
    
    def __init__(self, nome, num):
        self.nome = nome
        self.num = num
        self.cnt_pensou = 0
        self.cnt_comeu = 0
        self.cnt_garfo = 0
        
    def  eat(self):
        print("\n[{}][{}:{}] Iniciou a comer."
              .format(datetime.now().strftime('%d-%m-%Y %H:%M:%S'),self.nome,self.num))
        self.cnt_comeu += 1
        sleep(randrange(1,5))# indeterminismo
        print("\n[{}][{}:{}] Terminou de comer."
              .format(datetime.now().strftime('%d-%m-%Y %H:%M:%S'),self.nome,self.num))
        pass
    
    def  put_fork(self):
        if self.__n_forks > 0:
            self.__n_forks -= 1
            Filosofo.all_forks += 1
            if self.__n_forks == 1:
                print("\n[{}][{}:{}] Soltou o primeiro garfo."
                      .format(datetime.now().strftime('%d-%m-%Y %H:%M:%S'),self.nome,self.num))
            elif self.__n_forks == 0:
                print("\n[{}][{}:{}] Soltou o segundo garfo."
                      .format(datetime.now().strftime('%d-%m-%Y %H:%M:%S'),self.nome,self.num))
        pass
    
    def  take_fork(self):
        while(Filosofo.all_forks < 1):
            if self.__n_forks == 0:
                print("\n[{}][{}:{}] Aguardando o primeiro garfo."
                  .format(datetime.now().strftime('%d-%m-%Y %H:%M:%S'),self.nome,self.num))
            elif self.__n_forks == 1:
                print("\n[{}][{}:{}] Aguardando o segundo garfo."
                  .format(datetime.now().strftime('%d-%m-%Y %H:%M:%S'),self.nome,self.num))
            sleep(randrange(1,5))# indeterminismo
        self.cnt_garfo += 1
        self.__n_forks += 1
        Filosofo.all_forks -= 1
        if self.__n_forks == 1:
            print("\n[{}][{}:{}] Pegou o primeiro garfo."
                  .format(datetime.now().strftime('%d-%m-%Y %H:%M:%S'),self.nome,self.num))
        elif self.__n_forks == 2:
            print("\n[{}][{}:{}] Pegou o segundo garfo."
                  .format(datetime.now().strftime('%d-%m-%Y %H:%M:%S'),self.nome,self.num))
        pass
    
    def  think(self):
        print("\n[{}][{}:{}] Está pensando..."
              .format(datetime.now().strftime('%d-%m-%Y %H:%M:%S'),self.nome,self.num))
        self.cnt_pensou += 1
        sleep(randrange(1,5))# indeterminismo
        print("\n[{}][{}:{}] Ficou faminto."
              .format(datetime.now().strftime('%d-%m-%Y %H:%M:%S'),self.nome,self.num))
        pass

    def exist(self):
#       Ciclos de realizações
        for i in range(1,3):
            self.think();
            self.take_fork();
            self.take_fork();
            self.eat();
            self.put_fork();
            self.put_fork();
            print("\n")
            print(self.__dict__)

# %%
for i in range(1,2):
    f = Filosofo("FILOSOFO",i)
    t = Thread(target=f.exist)
    t.start()
# Out:
# [10-03-2019 17:28:18][FILOSOFO:1] Está pensando...
#
# [10-03-2019 17:28:21][FILOSOFO:1] Ficou faminto.
#
# [10-03-2019 17:28:21][FILOSOFO:1] Pegou o primeiro garfo.
#
# [10-03-2019 17:28:21][FILOSOFO:1] Pegou o segundo garfo.
#
# [10-03-2019 17:28:21][FILOSOFO:1] Iniciou a comer.
#
# [10-03-2019 17:28:25][FILOSOFO:1] Terminou de comer.
#
# [10-03-2019 17:28:25][FILOSOFO:1] Soltou o primeiro garfo.
#
# [10-03-2019 17:28:25][FILOSOFO:1] Soltou o segundo garfo.
# {'nome': 'FILOSOFO', 'num': 1, 'cnt_pensou': 1, 'cnt_comeu': 1, 'cnt_garfo': 2, '_Filosofo__n_forks': 0}
#
# [10-03-2019 17:28:25][FILOSOFO:1] Está pensando...
#
# [10-03-2019 17:28:29][FILOSOFO:1] Ficou faminto.
#
# [10-03-2019 17:28:29][FILOSOFO:1] Pegou o primeiro garfo.
#
# [10-03-2019 17:28:29][FILOSOFO:1] Pegou o segundo garfo.
#
# [10-03-2019 17:28:29][FILOSOFO:1] Iniciou a comer.
#
# [10-03-2019 17:28:33][FILOSOFO:1] Terminou de comer.
#
# [10-03-2019 17:28:33][FILOSOFO:1] Soltou o primeiro garfo.
#
# [10-03-2019 17:28:33][FILOSOFO:1] Soltou o segundo garfo.
# {'nome': 'FILOSOFO', 'num': 1, 'cnt_pensou': 2, 'cnt_comeu': 2, 'cnt_garfo': 4, '_Filosofo__n_forks': 0}
