# %%
from datetime import datetime 
from time import sleep, strftime, gmtime
from threading import Thread
from random import randrange

# %%
class Filosofo:
    
    __n_forks = 0
    __cnt_pensou = 0
    __cnt_comeu = 0
    __cnt_garfo = 0
    all_forks = 5
    
    def __init__(self, nome, num):
        self.nome = nome
        self.num = num
        
    def  eat(self):
        print("\n[{}][{}:{}] Iniciou a comer."
              .format(datetime.now().strftime('%d-%m-%Y %H:%M:%S'),self.nome,self.num))
        self.__cnt_comeu += 1
        sleep(randrange(1,1))# indeterminismo
        print("\n[{}][{}:{}] Terminou de comer."
              .format(datetime.now().strftime('%d-%m-%Y %H:%M:%S'),self.nome,self.num))
        pass
    
    def  put_fork(self):
        if self.__n_forks > 0:
            self.__n_forks -= 1
            Filosofo.all_forks += 1
            if self.__n_forks == 1:
                print("\n[{}][{}:{}] Soltou o primeiro garfo."
                      .format(datetime.now().strftime('%d-%m-%Y %H:%M:%S'),self.nome,self.num))
            elif self.__n_forks == 0:
                print("\n[{}][{}:{}] Soltou o segundo garfo."
                      .format(datetime.now().strftime('%d-%m-%Y %H:%M:%S'),self.nome,self.num))
        pass
    
    def  take_fork(self):
        while(Filosofo.all_forks < 1):
            if self.__n_forks == 0:
                print("\n[{}][{}:{}] Aguardando o primeiro garfo."
                  .format(datetime.now().strftime('%d-%m-%Y %H:%M:%S'),self.nome,self.num))
            elif self.__n_forks == 1:
                print("\n[{}][{}:{}] Aguardando o segundo garfo."
                  .format(datetime.now().strftime('%d-%m-%Y %H:%M:%S'),self.nome,self.num))
            sleep(randrange(1,5))# indeterminismo
        self.__cnt_garfo += 1
        self.__n_forks += 1
        Filosofo.all_forks -= 1
        if self.__n_forks == 1:
            print("\n[{}][{}:{}] Pegou o primeiro garfo."
                  .format(datetime.now().strftime('%d-%m-%Y %H:%M:%S'),self.nome,self.num))
        elif self.__n_forks == 2:
            print("\n[{}][{}:{}] Pegou o segundo garfo."
                  .format(datetime.now().strftime('%d-%m-%Y %H:%M:%S'),self.nome,self.num))
        sleep(5)
        pass
    
    def  think(self):
        print("\n[{}][{}:{}] Está pensando..."
              .format(datetime.now().strftime('%d-%m-%Y %H:%M:%S'),self.nome,self.num))
        self.__cnt_pensou += 1
        sleep(randrange(1,5))# indeterminismo
        print("\n[{}][{}:{}] Ficou faminto."
              .format(datetime.now().strftime('%d-%m-%Y %H:%M:%S'),self.nome,self.num))
        pass

    def exist(self):
#       Ciclos de realizações
        for i in range(1,3):
            self.think();
            self.take_fork();
            self.take_fork();
            self.eat();
            self.put_fork();
            self.put_fork();
            print(self.__dict__)

# %%
f1 = Filosofo("FILOSOFO",1)
f2 = Filosofo("FILOSOFO",2)
f3 = Filosofo("FILOSOFO",3)
f4 = Filosofo("FILOSOFO",4)
f5 = Filosofo("FILOSOFO",5)

t1 = Thread(target=f1.exist)
t2 = Thread(target=f2.exist)
t3 = Thread(target=f3.exist)
t4 = Thread(target=f4.exist)
t5 = Thread(target=f5.exist)

t1.start()
t2.start()
t3.start()
t4.start()
t5.start()
# Out:
# [10-03-2019 18:25:12][FILOSOFO:1] Está pensando...
#
# [10-03-2019 18:25:12][FILOSOFO:2] Está pensando...
#
# [10-03-2019 18:25:12][FILOSOFO:3] Está pensando...
#
# [10-03-2019 18:25:12][FILOSOFO:4] Está pensando...
#
# [10-03-2019 18:25:12][FILOSOFO:5] Está pensando...
#
# [10-03-2019 18:25:13][FILOSOFO:2] Ficou faminto.
# [10-03-2019 18:25:13][FILOSOFO:1] Ficou faminto.
#
# [10-03-2019 18:25:13][FILOSOFO:2] Pegou o primeiro garfo.
#
#
# [10-03-2019 18:25:13][FILOSOFO:1] Pegou o primeiro garfo.
#
# [10-03-2019 18:25:13][FILOSOFO:4] Ficou faminto.
#
# [10-03-2019 18:25:13][FILOSOFO:4] Pegou o primeiro garfo.
#
# [10-03-2019 18:25:16][FILOSOFO:3] Ficou faminto.
#
# [10-03-2019 18:25:16][FILOSOFO:3] Pegou o primeiro garfo.
#
# [10-03-2019 18:25:16][FILOSOFO:5] Ficou faminto.
#
# [10-03-2019 18:25:16][FILOSOFO:5] Pegou o primeiro garfo.
#
# [10-03-2019 18:25:18][FILOSOFO:2] Aguardando o segundo garfo.
#
# [10-03-2019 18:25:18][FILOSOFO:1] Aguardando o segundo garfo.
#
# [10-03-2019 18:25:18][FILOSOFO:4] Aguardando o segundo garfo.
#
# [10-03-2019 18:25:21][FILOSOFO:2] Aguardando o segundo garfo.
#
# [10-03-2019 18:25:21][FILOSOFO:5] Aguardando o segundo garfo.
#
# [10-03-2019 18:25:21][FILOSOFO:3] Aguardando o segundo garfo.
#
# [10-03-2019 18:25:21][FILOSOFO:1] Aguardando o segundo garfo.
#
# [10-03-2019 18:25:22][FILOSOFO:4] Aguardando o segundo garfo.
#
# [10-03-2019 18:25:22][FILOSOFO:5] Aguardando o segundo garfo.
#
# [10-03-2019 18:25:22][FILOSOFO:2] Aguardando o segundo garfo.
#
# [10-03-2019 18:25:23][FILOSOFO:4] Aguardando o segundo garfo.
#
# [10-03-2019 18:25:23][FILOSOFO:3] Aguardando o segundo garfo.
#
# [10-03-2019 18:25:23][FILOSOFO:1] Aguardando o segundo garfo.
#
# [10-03-2019 18:25:24][FILOSOFO:3] Aguardando o segundo garfo.
#
# [10-03-2019 18:25:25][FILOSOFO:4] Aguardando o segundo garfo.
#
# [10-03-2019 18:25:26][FILOSOFO:5] Aguardando o segundo garfo.
#
# [10-03-2019 18:25:26][FILOSOFO:2] Aguardando o segundo garfo.
#
# [10-03-2019 18:25:27][FILOSOFO:4] Aguardando o segundo garfo.
#
# [10-03-2019 18:25:27][FILOSOFO:1] Aguardando o segundo garfo.
#
# [10-03-2019 18:25:28][FILOSOFO:4] Aguardando o segundo garfo.
#
# [10-03-2019 18:25:28][FILOSOFO:3] Aguardando o segundo garfo.
#
# [10-03-2019 18:25:29][FILOSOFO:2] Aguardando o segundo garfo.
# [10-03-2019 18:25:29][FILOSOFO:4] Aguardando o segundo garfo.
#
#
# [10-03-2019 18:25:30][FILOSOFO:5] Aguardando o segundo garfo.
#
# [10-03-2019 18:25:31][FILOSOFO:1] Aguardando o segundo garfo.
#
# [10-03-2019 18:25:32][FILOSOFO:2] Aguardando o segundo garfo.
#
# [10-03-2019 18:25:32][FILOSOFO:3] Aguardando o segundo garfo.
#
# [10-03-2019 18:25:33][FILOSOFO:1] Aguardando o segundo garfo.
#
# [10-03-2019 18:25:33][FILOSOFO:4] Aguardando o segundo garfo.
#
# [10-03-2019 18:25:34][FILOSOFO:1] Aguardando o segundo garfo.
#
# [10-03-2019 18:25:34][FILOSOFO:5] Aguardando o segundo garfo.
#
# [10-03-2019 18:25:34][FILOSOFO:2] Aguardando o segundo garfo.
#
# [10-03-2019 18:25:34][FILOSOFO:4] Aguardando o segundo garfo.
#
# [10-03-2019 18:25:35][FILOSOFO:5] Aguardando o segundo garfo.
#
# [10-03-2019 18:25:36][FILOSOFO:1] Aguardando o segundo garfo.
#
# [10-03-2019 18:25:36][FILOSOFO:3] Aguardando o segundo garfo.
#
# [10-03-2019 18:25:36][FILOSOFO:4] Aguardando o segundo garfo.
#
# [10-03-2019 18:25:37][FILOSOFO:2] Aguardando o segundo garfo.
#
# [10-03-2019 18:25:37][FILOSOFO:3] Aguardando o segundo garfo.
#
# [10-03-2019 18:25:38][FILOSOFO:1] Aguardando o segundo garfo.
#
# [10-03-2019 18:25:38][FILOSOFO:4] Aguardando o segundo garfo.
#
# [10-03-2019 18:25:39][FILOSOFO:5] Aguardando o segundo garfo.
#
# [10-03-2019 18:25:39][FILOSOFO:1] Aguardando o segundo garfo.
# [10-03-2019 18:25:39][FILOSOFO:2] Aguardando o segundo garfo.
# [10-03-2019 18:25:39][FILOSOFO:3] Aguardando o segundo garfo.
